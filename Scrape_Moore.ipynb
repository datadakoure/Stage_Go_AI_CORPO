# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def url_to_soup(url:str):
    
    response = requests.get(url)
    
    # Vérifier que la requête a été réussie
    if response.status_code != 200:
        print(f"Erreur de requête: {response.status_code}")
        return []
    
    # Parser le contenu HTML de la page avec BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# %%
def scrape_page(url):
    dic = {}
    dic2 = {}
    dic["mos"] = []
    dic["fr"] = []
    dic["en"] = []
    
    soup = url_to_soup(url)

    # Trouver les éléments contenant les phrases en mooré
    examples_contents = soup.find_all('span', class_="examplescontents")
    
    for examples_content in examples_contents:
        
        #Mooré
        phrases_moore_exemples = examples_content.find('span', class_="example").text.strip()

        try:
            

            phrases_others_exemples = examples_content.find('span', class_="translation")
            
    
            
            #Français
            phrases_fr_exemples = phrases_others_exemples.find("span", lang="fr").text.strip()
            
            #Englais
            phrases_en_exemples = phrases_others_exemples.find("span", lang="en").text.strip()
            dic["mos"].append(phrases_moore_exemples)
            dic["fr"].append(phrases_fr_exemples)
            dic["en"].append(phrases_en_exemples)
            
        except:
            ...
            # dic["mos"].append(phrases_moore_exemples)
            # dic["fr"].append(phrases_moore_exemples)
            # dic["en"].append(phrases_moore_exemples)

    
    #phrases = [phrase_moore.text.strip() for phrase_moore in phrases_moore_exemples ]
    
    #phrases_moore = soup.find_all('span', lang="mos")  # Remplacez 'vernacular' par la classe appropriée si nécessaire
    # Extraire les phrases en mooré
    return dic

# %%
base_url = 'https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=a&lang=en'
soup= url_to_soup(base_url)
letters = soup.find_all('div', class_="lpTitleLetterCell")
letters = [letter.text.strip() for letter in letters]

# %%
def extract_url(letters) -> list:
    urls = []
    for letter in letters:
        url_page = f"https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter={letter}&lang=en"
        nbr_pages = url_to_soup(url_page).find("li", class_="page_info")
        
        if nbr_pages:
            
            nbr_pages=nbr_pages.text.split(" ")[-1]
            
            for i in range(1, int(nbr_pages)+1):
                url_page_2 = f"https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter={letter}&lang=en&pagenr={i}"
                urls.append(url_page_2)
        else:
            urls.append(url_page)
    return urls

urls = extract_url(letters)

# %%
def scrape_all_pages(base_url):
    
    dic = {}
    dic["mos"] = []
    dic["fr"] = []
    dic["en"] = []
   
    for url in base_url:
        print(url)
        
        url_dic = scrape_page(url)
        dic["mos"].extend(url_dic["mos"])
        dic["fr"].extend(url_dic["fr"])
        dic["en"].extend(url_dic["en"])
        
    return dic

# %%
def save_to_csv(phrases, filename):
    df = pd.DataFrame(phrases)
    df.to_csv(filename,sep="\t", index=False)
    print(f"Données enregistrées dans {filename}")

# %%
filename = 'phrases_moore2.csv'

# Scraper toutes les pages et sauvegarder les données dans un fichier CSV
phrases = scrape_all_pages(urls)
# Out:
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=-&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=a&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=a&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=a&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=ã&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=ã&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=40
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=41
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=42
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=43
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=44
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=b&lang=en&pagenr=45
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=d&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=e&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=ẽ&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=f&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=g&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=h&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=h&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=i&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=40
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=41
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=42
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=43
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=44
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=45
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=46
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=47
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=48
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=49
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=50
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=51
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=52
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=53
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=54
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=55
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=56
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=57
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=58
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=59
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=60
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=61
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=62
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=63
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=64
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=65
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=66
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=67
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=68
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=69
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=70
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=k&lang=en&pagenr=71
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=l&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=m&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=n&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=o&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=õ&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=p&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=r&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=40
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=41
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=42
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=43
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=44
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=s&lang=en&pagenr=45
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=40
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=41
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=t&lang=en&pagenr=42
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=ũ&lang=en
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=v&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=w&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=29
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=30
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=31
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=32
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=33
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=34
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=35
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=36
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=37
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=38
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=39
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=40
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=41
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=42
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=43
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=44
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=y&lang=en&pagenr=45
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=1
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=2
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=3
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=4
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=5
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=6
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=7
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=8
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=9
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=10
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=11
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=12
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=13
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=14
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=15
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=16
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=17
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=18
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=19
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=20
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=21
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=22
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=23
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=24
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=25
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=26
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=27
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=28
# https://www.webonary.org/moore/browse/browse-vernacular-english/?key=mos&letter=z&lang=en&pagenr=29

# %%
phrases
# Out:
# {'mos': ['Biigã yãbame.',
#   'Yik-y-yã. Tʋʋm-y-yã.',
#   'A waame.',
#   'A baaba waame.',
#   'A Poll la a Zã.',
#   'A yiib la a tã ya a nu.',
#   'A koos-a-la zaamẽ. A koosa wed-moaagã zaamẽ.',
#   'Ra sak tɩ bendr wẽ a bal tɩ f sao a bal ye.',
#   'bɩ y tek yam n kos sugri. A sãn ka woto, mam na n waa yãmb nengẽ tao-tao n wa zab ne bãmb.',
#   'Weer a to.',
#   'Sɛgda a na wa a toore',
#   'Ninsaal yaa a wae, a ka tat piig ye.',
#   'Ka maand a boto ye, maana a woto.',
#   'La pag a ye n dag n be be tɩ bãag tar-a.',
#   'Ki ne nadeng k a ye ye.',
#   "A zagl pa reeg t'a goabg nug kiime ye.",
#   'Pag wa a zall na kuil a zalla.',
#   'Aba! Ya yaa a wãna?',
#   'Ad kamba.',
#   'Ada yaa mam bi-ribl mam sẽn yãke.',
#   'Ad kamba.',
#   'A rɩɩme n tɩge, n zĩnd be n zod arrr',
#   'Arzãn yaa nin-sõama zĩig Wẽnnaam nengẽ kũum poore.',
#   'Waaf da tara sɩlem n yɩɩd we-rũms nins fãa Zu-soab a Wẽnnaam sẽn maanã. Yẽ soka Awa tɩ yaa: «Rẽ yĩnga Wẽnnaam sɩd yeela yãmb tɩ y ra rɩ tɩɩg baa a ye sẽn be tɩɩsã zĩigẽ wã biisi?»',
#   "A ma wã gomame n yeel tɩ ayo! T'a yʋʋr na n yɩ a Zã.",
#   'Ayy, mam ka bool ye!',
#   'Ã ! Yaa fo bɩ?',
#   'Koomã. Biigã.',
#   'ka sakd «ãa» ye, sakda «naaba».',
#   'ra-ãbga',
#   'Wẽnd na kõ laafɩ. Amina!',
#   'Woto yaa ãnda rẽnda?',
#   'Yaa tɩ-ãsdga.',
#   'Seobgã kɩtame tɩ tɩɩgã wil bɛd ãs n dʋʋge.',
#   'Koomã ãsga pibrã.',
#   'Kʋlgã rɩɩme n dɩ n ãsem n kẽnge.',
#   'Yeel-b tɩ b wa.',
#   'B na n yãaga foo.',
#   'Ned ba a ye ka wa ye.',
#   "Ba t'a wa yã ...",
#   'Bool-ba.',
#   'M ba Zã waame.',
#   'Ba ne saagã sẽn niidã, a na n waa ka.',
#   'Ned ka tõe n bãng ba-bi ba-gãe ye.',
#   'Ba-raoog pãng la a yiri.',
#   'Bi-puglã ba-rãmb yɛɛsame.',
#   'Wẽnd n yẽesd ba-sãadg sɛɛga.',
#   'Soom-tʋʋlg sã n yi, ba-tʋʋlg n yõkd-a.',
#   'Ba-yir ka lobgd ne kugr ye, ba-yir lobgda ne tãn-dagre.',
#   'ligd-ba-zaaga',
#   'Bala, baa sobgã ne ko-pɛmã sakda bãmb noore.',
#   'Kẽng-y toor n tɩ bao mood zĩig ning yãmb sẽn tõe n paamẽ. La b ka na n boog yãmb tʋʋmdã baa bilf ye.»',
#   'Da maan-y yɩɩr ne bũmb baa fʋɩ ye.',
#   "Baa tɩ f sã n pa nong soaamb, bɩ f sak t'a tʋb waooga.",
#   "Biig pa mi t'a baaba pa naab / Wẽnd ye.",
#   'Neb fãa baadame.',
#   'Yãmb baad tɩ ka maam ye.',
#   'Baad-y kũunã.',
#   'Wa ka !',
#   'Wĩn-to-baaga.',
#   'Lar kʋʋda yẽbg pa baagd lar n lob koomẽ ye.',
#   'Weef sã n kaooge, a lebda a baarẽ.',
#   'A baas n kiime?',
#   'B zĩime tɩ ya babg la laad bala.',
#   'Babs f ma raagẽ.',
#   'Mam zɩ n yã nin-kãnga bada.',
#   'B pa tũ taab ye, b waa badem-badma.',
#   'So-badgã.',
#   'Badg-b la f ra naag-b taab ye.',
#   'A yɛsame n digd bag-bage.',
#   'Nif sẽn ne, ka bag n yet ye.',
#   'Zĩiga wɩnga baga.',
#   'Wa kẽ maasmẽ tɩ rũndã wĩntoogã yaa wĩnto-bagdga.',
#   'A taa so-bakẽ',
#   'Laafɩ bala. Yaa sɩd bala.',
#   'A ka na n tõog n wa ye, bala, a zoa wã yĩns zabdame.',
#   'fo kẽnga balaabtoogo',
#   'Wẽnd n band zoang ki.',
#   'Balg bɛngã la f bas ki wã.',
#   'B rag n sẽbda yẽnda ne bãense, n balg a nao wã ne kutu, la a rag n kaooda a sẽbdsã.',
#   'A yĩngã yaa balsende.',
#   'Mam baooda foo.',
#   'Kambã baooda koomã.',
#   'no-baolengo (no-tolengo)',
#   'Wẽnd kũun yɩɩd baoobo.',
#   "F sã n dat yũug n kʋ, f baooda no-kõbd n be a noore (la f yet t'a yõka noaaga).",
#   'Baoosgo, foo n são.',
#   'Baoosg fãa, fo ka tar bʋʋm ye.',
#   'Bar-pɛɛbd sã n fʋʋs nif n kong, bɩ wɩ-pɛɛbd vʋʋse.',
#   'A teedã rʋra bara.',
#   'a yĩnsã rʋga bara!',
#   'Baraar la a rog yã.',
#   'Koom gɩdgr zĩig sẽn me.',
#   'mam barame, m ka le tõe ye.',
#   'Yolgã wʋrgame tɩ ki wã barge.',
#   'Y barka. Wẽnd na kõ d nin daare.',
#   'Sẽemd sã n ka yiri yʋgempend n basd koom.',
#   'A sika a rɩɩbã n bas ne ned ning sẽn gũud teedã.',
#   'A sẽn ka bas yard ne nebã yĩnga, a ka sak tɩ b pɩʋʋg a soolmã n loog ye.',
#   'Bas-taal kae ne yũug hagiimd ye.',
#   'A yĩngã yaa tʋʋlg basa.',
#   'Ned basda baag a soab yĩnga.',
#   'Ned kõn bas kur n pʋgd kãan-woabg ye.',
#   'Bi-bãadga. Bi-bẽedga.',
#   'Ninsaal bɛy yaa bãag bala.',
#   'Wẽnd na gãneg-y bãane.',
#   'A zĩnd bãanem.',
#   'kẽnd-y bãanem-bãanem',
#   'Kooom-bãmba. Kom-kãensã',
#   'Bãmba waa ka zaamẽ.',
#   'bãmba waa ka zaame.',
#   'Bãmb zakã la woto.',
#   "A nobame t'a pʋga lebg bãmbre.",
#   'Tɩɩga bãmame.',
#   'yel-bãnde; tʋʋm-bãnde',
#   'Bãn daoa nodr kaam.',
#   'Bãneg f kẽnã.',
#   'A bãnesda wed-moose.',
#   'Tẽn-noog kae ye, bãng n zĩnd n be.',
#   'Bãngenlɛgsr gɛl pa wãbd me, solgdame.',
#   'Da solg seb-kãngã bãngr goamã ye, bala, wakat kolgame.',
#   "La rasem a nii daar sẽn ya biigã bãong kẽesg daarã, sẽn ta, b pʋda a yʋʋr t'a Zã.",
#   'Rogmã rasem a nii daare, b waa ne bi-bilfã n na n kẽes bãongo.',
#   'Ad yaa wĩntoog ra bãng yʋng bãong ye.',
#   'Kom-bãoonegã.',
#   'A bee be.',
#   'M bee ka.',
#   'Be-zʋʋr ka gãngd bugum ye.',
#   'sagbã pa moe tɩ kẽ ye, a midgame n ya bed-bede.',
#   'Ra rɩk f wẽ-bil n tek wẽ-bedr ye.',
#   'A yaa bilf n yɩɩd bõn-buud a taabã fãa, la a sẽn wa n bɩ, a yaa bedr n yɩɩd zẽed buud fãa.',
#   'Ned pa yãt pesg bedrem n lebg laagd ye.',
#   'Noor ka rɩt noog n togs beed ye.',
#   'a yaa beed soaba',
#   'Naoor a wãn la m ba-biig na n beeg maam tɩ mam kõ-a sugri?',
#   'Kõ-y tõnd d beegrã sugri, tɩ tõnd me kõta neb nins fãa sẽn beegd tõndã sugri.',
#   'a bʋda nangur-n-beell tɩ yi.',
#   'Laafɩ beeme.',
#   'Y baaba beeme?',
#   'Bala, tõnd sẽn beẽ wã, yaa we-rasempʋɩɩga.',
#   'y mok filim kãngã sẽn yaa wokã begs-begsã.',
#   'A beka soaambã ne rasaare n lubi.',
#   'A yẽndã yaa bel-bel n dat n lʋɩ.',
#   'Mam yẽnda bendame n dat n lʋɩ.',
#   'Bi-bɛɛg belem nooma keelem daare.',
#   'Goam ka yõo yaa muk ma la b bɛlgda. Goam ka yõod belgda muk ma.',
#   "F sã n belg yãag t'a koodame, a kɛɛda a baaba nao-bi.",
#   "tɩ a = t'a",
#   'Awa belsda a biigã.',
#   'Yaa sɩd-sɩd bɩ yaa belsem-belsem?',
#   'Mam paamda belsgo.',
#   "Saagã neng yaa bem-bem; tõe t'a ni.",
#   'Bõe rabeem n tar foo tɩ fo yɛs n bemd a woto?',
#   'ko-bendã.',
#   'Niisã bendga bãkã koom.',
#   'Nin-kẽem pa zoet beng-puudẽ zaalem ye, sã n pa bũmb n digd-a, yẽ n digd bũmbu.',
#   'Kuil beoogo.',
#   'Wẽnd na n kõt beoogo!',
#   'no-beosgo',
#   'A rʋga yogrã tɩ bɩ n berge.',
#   'A bẽeme n kaoos n yaool n ki.',
#   'Wi-kɩtã bẽe a nengã sõama.',
#   'Sagbã nan ket n yaa bẽ-bẽ.',
#   'A bẽedame.',
#   'Fuugã a sẽn da ningã yaa bẽend-bẽende.',
#   'Fu-bẽesem-bẽesem.',
#   'Yãk kiuugã yaood bilf n bẽgen yaa, tɩ f ka mi beoog ye.',
#   'A bɛ a roogã.',
#   'Mogd pa mokd bɛd n bas bãooneg ye.',
#   'F biigã bɛɛ?',
#   "bʋ-yãangã maanda bɛɛ', bɛɛ' n boond a kambã.",
#   'F sã n ka tar n kõt sãan, bɩ f kɩt tɩ bɛɛl wʋm-a.',
#   'Ko-bɛrg mengã ka be a yʋʋrẽ wã ye.',
#   'Biig yam pa yɩɩd a bɛlgd ye.',
#   'Rũndã bɛnd são beoog kurga.',
#   'Ned kam fãa wãb a taoore bɛnga.',
#   'F sã n zĩnd kɩɩg sikrẽ, f sã n pa yɩ kɩɩgã bɛya, f yɩta koambã bɛya.',
#   'Bi yaa bã-longdem.',
#   'A wata beoogo bi ra-yɩta.',
#   'F sã n kʋ / dig f bi-bɛɛga, f to bi-bɛɛg n kʋʋd-fo.',
#   'Tɩ-sõng fãa womda bi-sõama, la tɩ-wẽng fãa womda bi-yoodo.',
#   'Bi-sõng yaa neb fãa biiga.',
#   'A ya m bi-yende.',
#   'Bõe n digd-y tɩ y zoet bid-bidi woto?',
#   'Lik bida pʋgẽ.',
#   'A rũmdã bidgame.',
#   'Yʋʋrã bidgame tɩ koomã raage.',
#   'Pagã tʋka yʋʋrã bidimdi.',
#   'A Zã waame bii?',
#   "A zĩime t'a yamã ya bii.",
#   'Rũm-kɩɩmã maanda bii, bii n n boond bʋʋgã n dat n yõke.',
#   'nag-bila, nag-bi',
#   'Kʋɩlen-bila.',
#   '... bũmb nins sẽn ya tɩlɛ tɩ zĩnd bilf sãn paase.',
#   'Yaa bilf-bilf tɩ tab raadẽ.',
#   'Yaas bilfu.',
#   'Bi-bilf.',
#   'zu-bilga',
#   'sɩddd ...',
#   'weefã taoor ru wã ka tõe n bilg ye.',
#   'Bilim weefã n kẽes roogẽ.',
#   'Bãmb bilsa mukã ne nus n dat n bãng a sẽn date.',
#   'A baoo põosg n birg kamaangã.',
#   'Wi-bĩinfu.',
#   'Tɩɩgã tobame n bĩmi.',
#   'Nug pa bĩngi a pa rɩkd ye. / Nug sẽn bĩng n dɩkde.',
#   'Bɩ ya wa beoogo.',
#   'Ned bɩ rũnga?',
#   'Yãmb wʋmame bɩ?',
#   'Bɩ y yɩ pʋ-peelem dãmba.',
#   'Yʋʋm piig la a nu biig nan pa ta a bɩ-n-sar ye.',
#   'Yaa bɩgemd bɩ kãsre?',
#   'Tõnd tog n yaoome bɩɩ, bɩ d ka tog n yao?',
#   'Waoog taab la bɩɩm koom fʋrsda.',
#   'Bur maanda ne bɩle zom.',
#   'Weefã kẽnda bɩnde.',
#   'Yaa tʋʋlg bɩs-bɩse.',
#   'Sãabã zugda b boaagã.',
#   'Pag pa yɩɩd a boaand ye.',
#   'Wamã wẽnda taab la b ka boag ye.',
#   'yɛg-boagdenga.',
#   'kõ-m gʋ-boak tɩ m wãbe.',
#   'Ad yaa rasãn-boalenga.',
#   'Bob n pɩʋʋg yam wã yã, rẽ tɩ korg loog yã.',
#   'Wẽnd bobelle n bee a nengã zugu.',
#   'Namsgã yaa maam me bobelle.',
#   'Moaagã bobla sĩnmiigã a naafã.',
#   'A raa mui-bodgo.',
#   'A tuu bog-zulunga, n yẽbg roogã kugr zugu.',
#   'Rɩk-b n bogl taaba.',
#   'Foo la mam bogre.',
#   'A tuka bok n sel tɩɩga.',
#   'Ra sak tɩ kaamã bol m fuugã ye.',
#   'Yãmb tõe n booga weefã ligdi?',
#   'M ma boondame.',
#   'A Zã boolgo.',
#   'Ned sakda boolle, n tõdg / zãgs tʋntʋmde.',
#   'A kẽnga tẽng a yembr sẽn boond tɩ Kaya.',
#   'Mam wʋma m biigã bore.',
#   'Yãmb boonda maam tɩ karen-saamba, la yãmb sẽn yetã zemsame, bala, mam sɩd yaa boto.',
#   'Taan-botre.',
#   'Bõan-nana poor n kũkdi.',
#   'Bõas n be yɩng n bõsdẽ.',
#   'Yaa bõe?',
#   'Yʋʋrã sẽn lʋɩ wã, a wãa bõg-bõge.',
#   'Tõnd yãnda bõn-bãnd rũndã.',
#   'Ad bõn-daoogo! Ad a lala!',
#   'Nang sẽn yeel a kamb tɩ b yik tɩ b kẽ tɩ yɩng yaa bõn-dũmdi.',
#   'Wẽnnaam miime tɩ yãmb data bõn-kãense.',
#   'Bõe n na n kɩt tɩ mam bãng bõn-kãnga?',
#   'nanguri, bɛnga',
#   'Mam kom-bãoonego, lak-y y mens ne wẽn-naandsã.',
#   'Bõn-nana ka tar gãong n sɩɩgd waoog ye.',
#   'Bõn-paall wɩɩda a soaba.',
#   'Bõn-wẽng zʋʋr gãta woko.',
#   'Samd são bõne.',
#   'Sag-bõonde.',
#   'B bõosa bãmb ne pẽdgr n yeele: «Rao-kãngã zemsame tɩ y maan a sẽn kotã n kõ-a.»',
#   'Bõs-rãmba kisa taaba, la wagda nonga taaba.',
#   'A bõs tɩ m sõng-a.',
#   'Mam na n bõsa sore.',
#   'A moona koe-noogã ne bu-zẽmsã me tɩ b wʋme.',
#   'Noor bug-raoogo pa wẽed n yõsg ye.',
#   'Bag yir zãra, bug-tẽng n pẽ.',
#   'B bug kambã tɩ b gũsi',
#   'Nem-bugri.',
#   'Ko-bugri.',
#   'Kɩɩm geta ned wĩntoog n yaool n bugs-a yʋngo.',
#   'Base! Base! pa bugum to ye.',
#   'Bõn-wẽng maasem pa sẽn na bui-fʋ ye.',
#   'Pag pa nong a pʋg-to biig kõn buk tulli.',
#   'Beoog tɩ beoog tɩ m buk m taamde.',
#   'A bul n maana bõe tɩ b pãbd-a woto?',
#   'D data buri.',
#   'Buud gomde, buud n kelgde.',
#   'Wagda sã n yi taaba, bũmb soaba paama a bũmbu.',
#   'A Tarkorg n dɩt a Kakorg bũmbu.',
#   'Da bʋ-y ned bʋʋd ye, la b kõn bʋ yãmb bʋʋd ye.',
#   'Bõn-dat ka bʋʋd a lem-wãar ye.',
#   'A bʋtame.',
#   'Yaa kom-bʋdo?',
#   'Kẽng bʋ-bʋge.',
#   'Bag sã n bʋg-f, bɩ f bʋg f menga.',
#   'A zoobdã bʋgame.',
#   'Wakat bʋgo? Fo rata wed bʋgo?',
#   'Sũkun-daoog gõntame tɩ na bʋgsa.',
#   'Zom-bʋka.',
#   'Zẽed yaa saalg bʋla.',
#   'Nebã gomda bʋr-bʋre.',
#   'A lʋɩɩ «pip».',
#   'Bas-y bʋrg paasda bʋrgo.',
#   'Yãmb data bʋse?',
#   'Sagl tɩ pas reeg bʋta vãto.',
#   'Pãng sã n tũud sore, bʋʋm bʋta moogo.',
#   'Sẽm moon-a raag n kʋʋd a bʋʋga.',
#   'Biigã zoeeme n bʋʋg a baaba.',
#   'Fo tara bʋʋm.',
#   'Rĩm sã n zoet bʋʋre, bɩ a lebs naam.',
#   'D wʋmame. D yɩɩle.',
#   'A wʋmame. A wʋmdame.',
#   'B da waame.',
#   'D ra kẽng ye.',
#   'Bi-yam n daad a ma samsa.',
#   'Daag yi laafɩ, yaa pagb n loe bãongo.',
#   'Koom sã n bidg n daage, yʋʋr ketame, f ye lebda kʋlgẽ.',
#   'Soaamb sũ-noog raare, a zug kẽeda waoogẽ.',
#   'Daare saagã na ni rũndã.',
#   'Mam dabda raaga.',
#   'Fo waa dabʋre?',
#   'A dag n waa ka.',
#   'M data koom.',
#   'Biigã rata rɩɩbo.',
#   'A Poll dãmba.',
#   'M kõn deem ne biig deemda f yembre.',
#   'Wudg-y sã n deng taoore, yals-y pa tõe ye.',
#   'Dẽ, a Maari yeelame yaa: Mam yaa Zu-soabã tʋmtʋmd poaka.',
#   'Dẽ poore, a Zã kẽnga Bobo soolmẽ.',
#   "Zu-soaba, mam ma-bi-poakã sẽn bas maam m yembr tɩ m get seglgã yellã, ka namsd yãmba? Dẽ wã yaa, yeel-y-yã-a t'a sõng-ma.",
#   'Mam yaa Alfa la Omega, dẽenem la yaoolem, sɩngr la sɛɛbo.',
#   'Fo rẽnda la woto.',
#   'A fuugã yaa sablg diga.',
#   'Rɩk kugrã n rĩ sɛbã tɩ sobgã na n dɩkame.',
#   'Ned pa pengd a to ger n dĩng wĩir / gĩsg ye.',
#   'A dɩta mui.',
#   'Bugum n dɩ raoogã.',
#   'A rɩta a ligd zãnga.',
#   'Sʋʋgã rɩtame.',
#   'Naabã dɩta tẽngã naam.',
#   'A pʋgã weoogame n lebg rɩga.',
#   'Ad sẽn dɩg tẽnga.',
#   'Sẽn dɩɩm ka põsd wĩndg ye.',
#   'Koom dɩta a mita.',
#   'Wa ges-do.',
#   'Doaag yaa nag-bil n pʋgd a soaba.',
#   'Pagã doga bi-ribla.',
#   'Rɩk laagã n rogl rʋkã zugu.',
#   'Dok laagã sẽn be lalgã zugã.',
#   'Wakat-kãng bala, a roogame n kõ Wẽnnaam waoogre.',
#   'Pa sẽn dõb fãa n sãad ye.',
#   'M pa rɩkd m gɛl n dõos samsa ye.',
#   'Tãoosã rõonsa a tãp n gũusd we-rũms n na n tão.',
#   'Ning-y tɩ pid n duki.',
#   'zĩunfã kii koomẽ wã n duk n tondẽ.',
#   'Gese, mam segla rɩɩb n sɛ. Mam kʋʋ niig ne dũm-nobdse, la bũmb fãa sɛglame n sɛ.',
#   'A rɩɩme n sa n dũmsd laagã.',
#   'Mam ka kẽng tʋʋmd dũndã ye.',
#   'peosg yaa yir dũnga.',
#   'Arzɛk paoog dũni rãmba, la kũum na sek-b zãnga.',
#   'Be-bɛɛg nintãm dʋʋgda a yãoogẽ.',
#   'Tõnd koosda futu, ed zoe n paama yõodo.',
#   'Raagẽ. Zaamẽ.',
#   'M bãngẽ pĩnda m ka waẽ ka ye.',
#   'A waẽ la! A waẽ wɛ!',
#   'Ka foo la a yãẽ ye.',
#   'Ẽhẽe, yaa woto la?',
#   '«Ne y kẽnde.» «Ẽyyn.»',
#   'F sã n gãe f to pĩirẽ, f gãee tẽnga.',
#   'F pa nong ned me, f nong f yʋʋre.',
#   'Fuugã yaa faaga.',
#   "Wobg sã n yet t'a faagẽ me, a são yõngre.",
#   'Weefã pĩni siga zãng faga.',
#   'Fuugã yaa pɛɛlg faga.',
#   "A rɩta mui daar fã t'a yam fake.",
#   'A moee sagbã fal-fal n kõ bãada.',
#   'A wanda beem n dɩt a falenga.',
#   "A peka a fuugã t'a lebg pɛɛlg falll.",
#   'Yaa faoore. Ad yaa faoore!',
#   'Fuugã yaa pɛɛlg fara.',
#   'A nengã lebga fayy.',
#   'Y fãa wa.',
#   'A vʋʋsa fãa...',
#   'Wẽnnaam zẽka a Zezi tɩ b be bãmb rɩtgo n yaa rĩmã la fãagda.',
#   'A Zezi fãaga tõnd n yiis likã pãngẽ.',
#   'Yaa Wẽnnaam barkã yĩng la yãmb paam fãagre.',
#   'Ba fãeega maam koom.',
#   'Fãoob pa lubd lalg ye.',
#   'Fẽes f yõ-fãtã.',
#   'Fe n ning pãnga.',
#   'Nug-febelle.',
#   'A yãsame n febendẽ tɩ m ka wʋmd a goama ye.',
#   'Bɩ bʋ-kaoodbã fees yellã neere.',
#   'Rɩ-nana feooda yẽna.',
#   'Bʋta sẽn fẽrgd bõn-buudã, kẽer lʋɩɩ sor kɩrenga.',
#   'Yaa zĩ-fẽbgdem.',
#   'Zĩigã fẽbga koomã.',
#   'Neb tus‑tusa tigma taaba, n sẽbg taaba, tɩ ya wa b na n fẽda taaba.',
#   'Yaa bul-fẽebdse.',
#   'A gesa fẽmm.',
#   'Sag-fẽoolle.',
#   'A fẽoosa kõbrã.',
#   'A yĩngã pida ne tʋʋl-biis fẽra.',
#   'Yaa taan-fẽta.',
#   'A fɛɛda wʋsgo.',
#   'Zĩigã yaa maasr fɛda.',
#   'Fɛɛs biigã n ges tɩ f bãngda fãa..',
#   'A loee wĩirã fibga.',
#   'Pagã fida a meng ne fu-paale.',
#   'A loee wĩirã fisg tɩ loke.',
#   'Tʋb-fiuk.',
#   'Zug sã n fiuugi, nin-zabr saame.',
#   'Kar-fiuungu.',
#   'Baa fɩ.',
#   'A fɩbga baagã ne sãbga.',
#   'Minim noog wãbda ne fɩɩba.',
#   'Koambã noor fɩɩgame.',
#   "Kɩɩg pa wʋmd fɩɩlgo t'a yõy ye yũn ye.",
#   'Yʋng pa fɩɩndã ya f bɛnd (bɩ roog) n pa yõk bugum.',
#   'A fɩk n lʋɩ.',
#   'A gomda fɩlem-fɩlem.',
#   'Zẽedã yaa fɩma.',
#   'A tũu so-fɩrg n salg n lʋɩ.',
#   "B ka loe naafã neer t'a fɩsg n looge.",
#   'Wẽnd na kõ-fo.',
#   'Fo kambã watame.',
#   'yaa bõe nem-fol-fole la woto?',
#   'A gomda ne foo.',
#   'Dũni yaa wãams roogo, bã,b tiid tɩ bãmb pogd n fooda.',
#   'A fooga baagã.',
#   'La foom, fo baood n maana bõn-kãsemse?',
#   'A kẽe roogẽ wã fõara.',
#   'Zug sã n beẽ, pugl ka fõg rũmd ye.',
#   'Ned ka yõgend fɩtla n fõgn-a ne peoogo.',
#   'A fõgna kut pugla.',
#   'A fõka a puglã n wõgemd n pʋʋs naaba.',
#   'Kõb-fõr-fõre.',
#   'Fuugã yaa pɛɛlg fõss.',
#   'Wẽnd na gũ-fu.',
#   'Safãndã fugda sõama.',
#   'A fugumda fuugã.',
#   'A furga pĩirã ne sʋʋga.',
#   'A wẽe furrr.',
#   'Da maan-y yɩɩr ne bũmb baa fʋɩ ye.',
#   'A fʋka a zãnde.',
#   'N kis baag n yaool n fʋrsd a bɩɩm?',
#   'Bur-maasa bee fʋʋrã pʋga',
#   'Pondr yeelame tɩ yaa fʋʋs taab n wãb yiu, ned ba a ye pa so yaoorã ye.',
#   "Zẽedã sɛɛme t'a gaad sagbã.",
#   'Sag-gaare.',
#   'A gaga bisã n rems a pʋgã.',
#   'Zu-galbre.',
#   'A segla rɩɩbã tɩ gale.',
#   'Bɛngã yaa galle, a womame.',
#   'Gals n bao mang-sõng n yãke.',
#   'Maan gar-gar tɩ d looge.',
#   'Gariibã garbdame.',
#   "A garga baagã t'a rũm-a.",
#   'Baagã gasga biigã.',
#   'pida gã.',
#   'Busl ka yãgd ne a gãag soab ye.',
#   'M waame n na n ges y gãaga.',
#   'Togs sɩd n gãand kom são yag zirẽ n dɩ sagbo.',
#   'Gomtɩʋʋg gãandame.',
#   'Kãnd sã n wogem me, a tara gãdb zĩiga.',
#   'Tõnd sã n yet tɩ yaa raoa, d gãda a lala. / Ad bõn-daoogo! Ad a lala!',
#   'M gãeeme.',
#   'B gãeemdame la?',
#   'Tẽng-n-ned gãeems pa zẽed ye.',
#   'Gãeeng sagb pa yõngd n kõ sãan ye.',
#   'Pida gãkɩ.',
#   'Gãm rũndã são gãm beoogo.',
#   'A yeesa a zab-teedã n yelg a Zã. Yẽnda fõgna a Zã zũud pugla, la a loe-a ne kut gãn-tika.',
#   'Ne mam Wẽnnaamã pãnga, mam gãndgda lalga. (Yɩɩn-sõamyã 18:30)',
#   'A ka tar zĩig sẽn na n gãneg a zug ye.',
#   'Gãneg koɛɛg n gome.',
#   'A gãng peoogã n looge.',
#   'M ma gãooga a nengã n get maam.',
#   'Võaagã gãoonme.',
#   'Tɩɩgã woma gãss.',
#   'La b geela sɛbã ligd n mik tɩ taa wakɩr tus pis‑nu.',
#   'Fo geenda f na n gãanda ka wɛ?',
#   'Biigã kẽnd n gend a zugã.',
#   'A pãnmame n dʋʋs gem-daoogo.',
#   'â',
#   'à',
#   'gʋ́lsgó',
#   'Pag zug wogem me a pa yɩɩd a geonf ye.',
#   "La yãmba, yãmb maan-a lame t'a lebg wagda geongo. (Mat 21:13)",
#   'Biiga ?',
#   'M wa f geosgo.',
#   'Fo sã n yet tɩ zug ka nemdo, bɩ f wẽbg f meng zug n gese.',
#   'Nebã fãa sẽn be be wã dag n geta yẽ.',
#   'Biig geta a to wamd n gẽ.',
#   'A gẽdma ki ne bɛng n bʋde.',
#   'Dao wã gẽegda sõama n yaool n tã.',
#   'Biigã ma gẽend-a lame.',
#   'Pa mi gẽenego, kall tus n lubi.',
#   'Sẽn wũg-a wã nee sẽn gẽesd-a wã.',
#   'A nugã gẽkame.',
#   'A gẽoog a nifã n get biigã.',
#   'Nin-gẽoog soaba.',
#   'Ki wã gẽooname.',
#   'Koomã pida kʋlgã noor gɛ.',
#   'Koadeng yet tɩ yõor la gɛla.',
#   'Warb / Saoog ka neer paka a gɛta.',
#   'B gilgda doogã noor a tã.',
#   'Ka wat n get-ma ka yell ye, lood n gind-ma, yẽ yaa zabre.',
#   'A ginda kaolgo.',
#   'B rɩɩ rɩɩbã gilli.',
#   'Mui-gila',
#   'Gind karg ka kaood ye.',
#   'Bĩndingãoosg yeelame tɩ sẽn sãad-a koaag ka mi te sẽn gind-a namsdame ye.',
#   'Zug koom pa gind neng ye.',
#   'A gĩdga wĩirã.',
#   'Yellã gĩd-a lame.',
#   'B gãd-a-la gĩmm.',
#   'Kamaan-gĩna.',
#   'Bĩis-naarã gĩsame.',
#   'sʋʋg sẽn ka rɩt yaa sʋ-gɩdga.',
#   "Gɩdg-a t'a ra loog ye.",
#   'Rũngã kii gɩfo.',
#   'Yũug la no-gɩɩga.',
#   "Gɩɩg biigã t'a lebg n wa ka.",
#   'Koomã gɩmbame n ka loogdẽ ye.',
#   'Tʋʋmã gɩmbame.',
#   "Biigã bɩɩme t'a fuugã lebg gɩnga.",
#   'Bur-gɩrga.',
#   'Nu-gɩʋngo.',
#   'Zãgs goabg rɩk tẽnga.',
#   'Muk ma n wʋmd a biig goama.',
#   'Tʋʋm-goaba.',
#   'Kabr gobr sɛgda ne a soaba.',
#   'Tẽng rãmb sã n pãbd gãngãad ne goeto, bɩ f me sao n kẽ gõose.',
#   'Noaagã goka biigã.',
#   'Ges lalgã yaa tɩrg bɩ a yaa golengo.',
#   'Kʋɩlg sã n golem, bɩ yẽbg tũ n golme.',
#   'dɩ, dɩɩbo',
#   'Gom-biis bilgri.',
#   'Gom-wẽng kae ye, tags-wẽng n be.',
#   'Gom-yook ka be ye, tags-yook n be.',
#   'Gomd ka kood pʋʋg la a welgda yelle.',
#   'M gomda moore.',
#   'A googda tɩɩgã willi.',
#   'Baagã goonda kõbre.',
#   'Yũuga gorga maam.',
#   'B ka wobd kankam gõaag zug ye.',
#   'Bɩ y gũus n da wa gõdg n sãam taab ye.',
#   'Sɩlg noor yaa gõdgo.',
#   'Koom sã n zoet lebende, a mii a gõdgr zĩiga.',
#   'M gõee pĩnda.',
#   'A gõgendame tɩ mam ka wʋmd a goam võor ye.',
#   'Wãamb nags-toogã la a biig neng ya gõko.',
#   'Sɩd sã n togsdẽ, zug gõmsda a toore.',
#   'Waafã gõnmame.',
#   'Zaamẽ beoog pʋʋsda yao tɩ kãsem zĩ gõo.',
#   'Ned kõn kɛ gõos n los koomẽ n kẽ n tab ye.',
#   'Koom sã n ka gudgi, a ka tisgd ye.',
#   'Nin-kʋʋd zoet guugu.',
#   'Baagã gũuda zaka.',
#   'Neb kʋʋng n dag n gũbg a Zã n pẽdgd taab n dat n wʋm a goamã.',
#   'Ãndã n na n dɩk paoong sɩd-sɩd n gũnug yãmba?',
#   'Ned pa tõe tɩ raag gũs ye.',
#   'Nid-yend pa gũud tʋgr ye.',
#   'D sẽn gũus n yãnde:',
#   'Gũus-m-meng la wi-kʋdre.',
#   'Gũus f menga.',
#   'A palga biigã gʋbla.',
#   'Taan-gʋɩɩga.',
#   'a, b, c, d, ...',
#   'Wag-kẽenfo pa sãamd a to gʋlsem ye.',
#   'Fo gʋlsgã yaa neere.',
#   'A gʋndame.',
#   'A gʋrga maam ne a nug-yẽesã.',
#   'Nin-kẽem sã n gʋsd noaag la a yɩɩndẽ, a yãbdame.',
#   'A gʋʋnda kĩini.',
#   'Noomame yẽ, la ha, ka nana ye.',
#   "Yɩ ha' tɩ m pãb-fo.",
#   'Haa tɩ m gese.',
#   'A habenda woto.',
#   'Mam habsd wa baag n boond-f tɩ f sĩnda.',
#   'Yaa hal Bobo.',
#   'Yɩɩ hal zaamẽ.',
#   '«Zu-soabã sõnga tõnd hal tɩ ta ka.»',
#   'A kula hal-hale.',
#   'A yaa a ba halaale.',
#   'A na wa halɩ.',
#   'M nong-f yẽ, la hao, la paka maam.',
#   'Haya! Wa-y tɩ d kẽnge.',
#   'Haya-haya n zẽkd roog sugri.',
#   'Hã! Kaare! Wa reeg wɛ!',
#   'Roogã noor sẽn pak hãa wã yaa bõe?',
#   'Yʋngo rot nins sẽn tar-b bugmã yaa hãmm....',
#   'A taka fuugã n pãrg hãrrr...',
#   "He', maan gũusgu!",
#   'Bõang hĩrsdame.',
#   'Wa ka.',
#   'B ka wa ye.',
#   'Ka maam ye.',
#   'Mam ka silmiig ye.',
#   'Ka maam la a pʋʋse ye.',
#   'Masã, tõnd ka na n ges bãmb woto yɛs ye.',
#   'F ka tar bʋʋm ye.',
#   'Ka yɩ maam ye.',
#   'Ad fo nemdã ka zug rũndã ye.',
#   "Ka-pãng naaf zombdame t'a gãe.",
#   'Ka-sãnd-sõng ka tat zɛɛgẽ ye.',
#   'Zãag-y ne maam, yãmb fãa sẽn tʋmd ka-tɩrlem tʋʋmã .',
#   "B yalsa woto ka' tɩ beoogã vẽege.",
#   'Kaag n ges a loogame.',
#   'Nin-kẽem kaagd n kaoogd a sag-wãre.',
#   'A kaaga koomã ne a nugã.',
#   'A zĩnda kaandr n yaool n kul sɩda.',
#   'Hal tɩ ta kaanẽ, Sẽn-Ka-Saab sõnga tõndo.',
#   'Ba-kaare.',
#   'Kaarɩsa! M yam ya n yi!',
#   "A pãba biigã t'a kaasdẽ.",
#   'B pãb-a-la ne kaase.',
#   'Kabg koomã n kõ-ma.',
#   'Fo sẽn tar kabl-kabl woto wã fo na n tõog n paka roogã?',
#   'A sẽbga maam wĩir tɩ m kabl n loke.',
#   'Y kabr tɩ m looge.',
#   'Y kabse, la b na pak tɩ y kẽ.',
#   'Kada soabã la m data.',
#   '... tɩ pʋ-peelem sã n kaẽ, ned ka tõe n yã Zu-soabã ye.',
#   'Fo reemda ne maam kae?',
#   'Rʋk sãn kaeed kɛgre, pʋ-to-ned n tus bugum.',
#   'Yellã kell n paa woto kafaabo.',
#   'Kak sẽn tũ zĩig ning n kẽ wã, a tũuda be n yi.',
#   "A kaka biigã t'a yãbda.",
#   'A geta kal-kale.',
#   'Bas wil-kãng la f kal a to.',
#   "Kall t'a wa.",
#   'Yel-kãngã sɩd yaa kall ne maam.',
#   'Piisã ne bʋʋsã kalma taaba.',
#   'Ned kam fãa.',
#   'Mobil-paall kama.',
#   'Bãmb kamsa b tũud-n-taasã sẽn dag n be koglg a to wã pʋgẽ, wã tɩ b wa sõng-ba.',
#   'Kams moodã n yõoge.',
#   'Kao bʋʋdo.',
#   'Mam baoome tɩ fo ra mii tiiri.',
#   'Naab sã n kao bʋʋdã, goamã saame.',
#   'No-ra-kaoglgo.',
#   'M zĩ m yembr kaoko.',
#   'bug-raoogã maan kaoo...',
#   '«La buudã fãa na n waa yãmb taoor n wa waoog yãmba, yãmb bʋʋdã kaoob sẽn yɩ vẽeneg ne nebã fãa wã yĩnga.»',
#   'Pag yao kuilb n kaood a gɛnda.',
#   'Pa so miuusg, pa kaoogd sʋk ye.',
#   'Kukur kaoogr zemsa ka-koaad yaamse.',
#   "M kaoolame t'a na n waame.",
#   'Sag-kaoolle.',
#   'Nao-kaoondo.',
#   'M kaoos n yã-f lame, são m yam yi-fu.',
#   'A zugu kaoosdame.',
#   'Pesg kaoosg la lomde.',
#   'Yagl f meng n yaool n yagl kapidgu.',
#   "Bas t'a wa. (tɩ a = t'a)",
#   'Saagã karsdame bala.',
#   'Rãamã saa zãng kas-kase.',
#   'A wẽ-a-la kasa n lubi.',
#   'Zabr ka sagb n gũud kasem ye.',
#   'Wam-kasemde.',
#   'Bi-kasenga.',
#   'A yaa dĩm-kasenga.',
#   'A wẽe biigã kasɩ.',
#   'Tʋʋmdã saa zãng kasɩ.',
#   'saagã sẽn ni wã pɩɩga zakã tɩ lebg kasɩ.',
#   "Ra paoog-a t'a yaa kasma.",
#   'ninsaan-katembaolengo',
#   'Kato! Ãnda n na n kelg maam?',
#   'A tʋka yʋʋrã kawɩla.',
#   "A wẽ-a-la kã' n lubi.",
#   'Wẽnnaam zoee tõnd yaab-rãmbã nimbãanega, n tẽeg bãmb kãab-sõngã yelle.',
#   "A kãabame t'a na n waame.",
#   'A kãaba bi-puglã tɩ Wẽnd na kõ-a sɩd-sõngo.',
#   'Rɩt yɩng ka be kãabg ye.',
#   'Ning-y neb nins sẽn kãabd yãmb wẽngã zut barka.',
#   'Baagã wãbda nem-kãado.',
#   'ges-kãaga',
#   'a wãba zĩm tɩ kõbr kãamd-a.',
#   'Mo-kãamd la b tar n pind doto.',
#   'Kambã tonga kãan-zʋʋre n kẽed karen-doogẽ wã.',
#   'Tẽng-n-ned kãar sãoo sãan nenga.',
#   'Rɩɩbã kãbgame.',
#   'A sũurã kãbgame.',
#   'A rɩɩ sagbã n ka kãbg maam ye.',
#   'Biigã lebga kãdemde.',
#   'A kẽnga kãdengẽ n na n tɩ maan a rogem sebre.',
#   'Raoog n kãdg a nugã.',
#   'A bɩɩme n kãdge.',
#   'Kãe n gomd ne fo?',
#   'Y sã n zab n tõog bũmb fãa, yãmb na yals kãenkãe.',
#   'Tʋʋm-kãense.',
#   'Weoogã kãgame tɩ ka tõe n loog ye.',
#   'A wãbe zĩm tɩ kõbr kãgemd-a.',
#   'Katr sã n pa paam kãgr-sõngo, a pa yõkd bʋʋg ye.',
#   "Kãms biigã t'a wa.",
#   'Bi-kãngã yii yɛ?',
#   'Bi-kãngã wã yẽ yii yɛ?',
#   'Lombrã kãgendame.',
#   'Kãnkãe sã n be taoore, yol-yol n pʋgde.',
#   'Kãnkãr ra wɩd a moog tɩ b fãa zãng yaa rʋda.',
#   'bi-kãongo',
#   'M ma kambã sʋka, maam la kãoogo.',
#   'Pʋg-kãoogo.',
#   'Kãsem yaa tãmpʋʋr sagdo.',
#   'Wam-kãsemde.',
#   'Ko-kãsenga.',
#   'Wĩirã kãsgame.',
#   'Ra paoog kãsma yaa f me na n wa yɩ kãsma.',
#   'Taan-kãsre.',
#   'Nem-kãtemde.',
#   'Ro-kedbre.',
#   'Kedemd bilf tɩ m looge.',
#   'Kedg n ges f poorẽ.',
#   'Kedem la f bas weere.',
#   'B keega tɩɩgã.',
#   'Y rɩka wamã n keelg taaba.',
#   'A keemame.',
#   'Pʋg-yãang keema a but wõdb raare.',
#   'Bõn-kegemde.',
#   'Nebã kẽnd n kekd taaba.',
#   'Kek tɩ m looge.',
#   'Liuul kelem n bool saag, la a na yoog a zugẽ.',
#   'A kelgda m biigã yelle.',
#   'M kelgda sõama.',
#   'A rɩɩ sagbã tɩ kelle.',
#   'A rɩɩ sagbã la a kell maam mui wã.',
#   'A kell n ka wa ka?',
#   'Kell n ko tɩ nan ka sɛ ye.',
#   'Sagbã kell la a kõ biigã.',
#   "Baag n dũm-a t'a kelemdẽ.",
#   'Ki wã ligd kengame.',
#   'A tʋmame tɩ b keo-a.',
#   "A Zã keooga yẽnda t'a ra gom bõn-kãng ne ned ye.",
#   'Tʋʋm-sõng tara keoore.',
#   "A karg n zabd t'a keoosdẽ.",
#   'A goamã keoosa bilfu.',
#   'Zĩ-keorengo.',
#   'F tʋma sõma la kesga bilfu.',
#   'Ket n ka sek ye.',
#   'Keta bilfu.',
#   'M kẽedame.',
#   'Ki wã ne mui kẽe taaba.',
#   'Raagã kẽeme.',
#   'Pa kẽ bãong pa kɩɩd pʋg wiy ye.',
#   'A kẽbga kaafã.',
#   'Biigã kelma kẽddd...',
#   'Ned fãa kẽebda a sẽn ko.',
#   "Katr yeelame t'a sã n tẽeg a zaamẽ rɩ-kʋda, a kẽeda tẽng ne wĩndga.",
#   'ka yaa mam zag-kẽedre.',
#   'Fu-kẽega.',
#   'Fu-kʋdgã kẽegame.',
#   'Yaa yẽ n kẽem tõnd fãa.',
#   'A tara sam-kẽenga.',
#   'Na-bi-kẽenga.',
#   'Neb-kẽere.',
#   'Kẽer me lʋɩɩ gõos sʋka.',
#   'Kẽes noosã',
#   'A kẽgsda a ki.',
#   "A naga zomã n bas tɩ kẽk t'a maan zom koom.",
#   'A kẽka maam tɩ m ka tõe n vʋʋs ye.',
#   'Yik pĩnd são kẽn- fãoodem.',
#   'Ne y kẽnd-kẽnde.',
#   'Da rɩk-y bũmb y kẽndã yĩng ye.',
#   'Kẽ n pa gõe, kẽndame tɩ zĩig yẽege.',
#   'Pagã kẽndame.',
#   'Bãagã kẽndame.',
#   'Kẽng ne biigã tɩɩm doogã.',
#   'B kẽnga raaga.',
#   'Wãkã rɩɩme n kẽre.',
#   'Wãg-kẽrga.',
#   'B kɛɛda tɩɩg ning fãa sẽn ka womd bi-sõama.',
#   'Ned ka zao will la a kɛɛd-a ye.',
#   'Bãmb tʋma kɛɛda tɩ rũm bãmba, la loms tɩ sãam bãmba.',
#   'Kɛɛg-wok tara tɩɩm, la kɛɛg-koɛɛg ka tar tɩɩm ye.',
#   'Kɛɛg-wok tara tɩɩm, la kɛɛg-koɛɛg ka tar tɩɩm ye.',
#   'A kɛɛga tɩɩgã ne karentɛ.',
#   'Koomã kɛɛgame.',
#   'Yibeoog kɛɛma?',
#   'Wa tɩ d kẽng kɛɛng baasda sʋka.',
#   'Nemdã yaa kɛɛnga.',
#   'B yiyã kɛga taaba.',
#   'Noaagã yaa nao-kɛgelle.',
#   'Yel-kɛgenga.',
#   'Kɛgl rʋgdã taaba.',
#   'Tʋʋm-kɛgre.',
#   'Kɛma a yiib sãgs n noome.',
#   'Yaa woto kɛpɩ.',
#   'Bugmã kiime.',
#   'Kiuugã kii rabʋre?',
#   'A fuugã kiime.',
#   'Y yĩns kibare?',
#   'A kibg zãnde.',
#   'Kibl biigã.',
#   'Sũma ka rʋg sõama tɩ kidbi.',
#   'Kamaan-kidba.',
#   'Raag kiib togsda a tilgr daare.',
#   'Pa ta kʋɩlg n yõng koom kiida ko-yũudu.',
#   'Kiig koomã.',
#   'La b rag n ka tar biig ye. Bala, a Elizabɛt da yaa kiiri.',
#   'Kiis bugmã.',
#   'Tɩɩm pa sat killẽ ye.',
#   'A tõe n kilmame n lebg katre.',
#   'F sã n sao n kẽng taoor n ka yãnd kilsg, bɩ f ra le sao n wa poorẽ ye.',
#   'Kils-y naabã!',
#   'Nag-kiri.',
#   'Hat yaa kirisned vʋʋsem daare.',
#   'Yaa bũmb sẽn kisi.',
#   'Ned sẽn nong a meng pa kis a to ye.',
#   'A zoet kiu-kiu.',
#   'Sagbã yaa kiuglg.',
#   'Tõnd buudã kiusg yaa yẽbg nemdo.',
#   'B kĩi ne taaba, b yaa ma-biisi.',
#   "Kugr lʋɩ kĩ'.",
#   'Biigã yãbdame n kĩgsdẽ.',
#   'Kĩin a yiib pa pag n mi zẽed ye. / Kĩin a yiib pa pag nug n noom ye.',
#   'A laadame n kĩkdẽ.',
#   'A paga roogã kĩm-kĩmi.',
#   'Bũmbã yaa bãooneg kĩm-kĩmi.',
#   'Roogã noor paga kĩma.',
#   'M ba-biig yaa mam kĩninkĩiga.',
#   'koomã yaa maasg kĩninnn...',
#   'Kɩ baafã ka n loe bʋʋgã.',
#   'Ned pa ningd a kɩb-kɩt yãnd ye.',
#   'Fo kɩbda yɛ?',
#   'Kãand kɩbgda ne kãan-sʋʋg tɩ lebg wama. Wam wãadga.',
#   'A yiisa kom-kɩdb a yiib tɩ b wa sõng-ma.',
#   'buglunvãrã kelma kɩddd...',
#   "A tʋbã kɩdame, t'a ka wʋmd sõama ye.",
#   'Pʋg-sad na kɩdem, bɩ a sok a pʋgdba.',
#   'Bi-kɩdga.',
#   'Bul-kɩdga.',
#   'Fo na n paama sũ-noog n kɩdme.',
#   'F sã n pa yãk f kɩgbr gõaaga, f pa tõe n yãk f naoor gõaag ye.',
#   'Ra bas tɩ kɩɩm kẽ roogẽ tɩ f yaool n pag ye.',
#   'Nemd tõe n kɩɩmame.',
#   'A kɩɩmda piisi.',
#   'F sã n ka mi tẽng kɩɩmse, f ka wẽed a bendr ye.',
#   'Ra wãb-y rũm-kɩɩng nemd ye.',
#   'Naoor sẽn kɩɩs a to la wobendo. / Nao kɩɩ taab la wobendo.',
#   'B kɩɩsame tɩ ka sɩd ye.',
#   'Kɩɩsg gomde.',
#   'Yẽ n wʋm yellã, n kɩk maam.',
#   'A paa kɩla.',
#   'kɩlem yaa rɩ-koosdem buud fãa.',
#   'Yʋʋrã kɩllame.',
#   'Sor kɩrenga.',
#   'Da kɩs kaset sẽn ya zirẽ n dõd f to ye.',
#   'Kɩs Wẽnd sɩda.',
#   'A kɩsa maam ligdã.',
#   'M kɩta yẽnda.',
#   'A na n kɩsga kuku-raoogã.',
#   'Wẽnnaam dag n kɩtame tɩ tɩɩs yi.',
#   'Begdã kɩʋʋlame.',
#   'Nug-kɩʋʋlle.',
#   'Koom beeme tɩ ko-sʋk beẽ.',
#   'Koom sẽn na n kiis bugum pa baood ko-yɩlemd ye.',
#   'Ko-zoetmã zoeeme n wẽ roogã, la a ka tõog n miim-a ye.',
#   'A wẽe kʋɩlengã koa-koa.',
#   'Bẽ-koaaga.',
#   'Nangur-n-koaasã zĩig la ka.',
#   'Bars-toog vẽnegda koaasd yam.',
#   'Ned gãag soab n gʋsd a koadenga.',
#   'Ko-koaka.',
#   'Lʋn-koatga pa wẽed n põomdedẽ ye.',
#   'Yaa kobsi.',
#   'A kodge noaagã.',
#   'Kodgr sã n ta boɛɛg, bɩ a nak a lemde.',
#   'Gũus f meng koe ! A ka wa koe?',
#   'Tõnd koe-zugã yaa «Pag ne sɩda vɩɩm».',
#   'Zu-koebelle.',
#   'Zĩ-koeelle.',
#   'F sã n wa mik tɩ mood lebg koeese, bɩ f zõond n wʋre.',
#   'Mam gʋlsa yãmb seb-koɛɛga.',
#   'Zĩ-koɛɛga.',
#   'Fo koga woto n dabd yɛ?',
#   'Wẽnd na kogl f yõore.',
#   'Yaa gɛl ne waooga, kogendame la pa wãad ye.',
#   'A pʋgã koglemdẽ.',
#   'Tar gãongo, n kogsd wẽng soabã pɛɛmã fãa.',
#   "Roogẽ wã yaa tʋʋlg t'a yi n na n kok pemsem.",
#   "Kok biigã t'a na n lʋɩɩme.",
#   'Kok rũmsã n kẽes b roogẽ.',
#   'B baoo barg n kok a zugã.',
#   'A Zã yõka yẽnda n sog a kokoɛy wã n yeel-a: «Yao maam m samdã.»',
#   'M kolga tẽngã noorẽ.',
#   'Pademd noor yita kolkood, pademd noor pa yit zɩɩm ye.',
#   'Rɩ tɩ yãag pa rigd beoog kom ye.',
#   'Rɩt n pa tɩgd n wa kẽ kom-gãaga.',
#   'Komindi yaa kãdenga meer sẽn so.',
#   'Tʋʋm-kidbã n koms-a.',
#   'Mobill n fão-a n koms-a.',
#   'B kaoo bʋʋdã n yet tɩ fo n kong bʋʋm.',
#   'Noor soab ka kongd sor ye.',
#   'A maoome n konge.',
#   'Tar m yam n kood maan-dẽenga.',
#   'Zĩ-koodre.',
#   'Nangur-koodo.',
#   'kool f nao wã la f bas sore.',
#   'Kool sagdã.',
#   'Tõnd pa rengd wʋʋg n lʋɩ koomẽ ye.',
#   'Mam yaa pĩ koosda.',
#   'Tab-noog n koosd a menga.',
#   'Yãmb koosda bõe?',
#   'Ned n koosd roogã noore.',
#   'M kota koom.',
#   'Wẽnnaam leoka pagã kosgo, la a rɩka pʋg n dog bi-ribla.',
#   'Bẽerã kaeeda kot-kot.',
#   'Karen-saamba, m kot-y lame tɩ y ges m bi-riblã.',
#   'M kõta foo ligdi.',
#   'Kõ n paas pa wẽ n paas ye.',
#   'Fo pag a Elizabɛt na n doga bi-ribl n kõ-fo.',
#   'Sĩif kõabnengã.',
#   'Kõat baooda yel-sõmde, tɩ zãgsd baood beem.',
#   'Kõbr zã n kaoos yooda baag yam.',
#   'Baag yĩngã kõda ne rẽgdo.',
#   'A kõgda rãamã tɩ ya beoogo.',
#   'Fo yaa kõgr woto la?',
#   'Fo kõn wa ye.',
#   'Wakat kõngo.',
#   'Yaa kõod wa rõodo.',
#   'A kõoga a zugã.',
#   'Zu-kõogo.',
#   'A sã n da bãngẽ, a kõon n waẽ ye.',
#   'A kõra zĩigã mood tɩ lebg neere.',
#   'A kõsda kõs-koɛɛnga.',
#   'Gõaag n kõs maam.',
#   'A kõs raagã sẽne.',
#   'Wẽnd na kõt laafɩ!',
#   'Nin-kõtre.',
#   'Kẽng lalgã kudga.',
#   'Sag-kudri.',
#   'B kuiisame.',
#   'Sãan yao kuilb a pegde a nus ko-yũudẽ.',
#   'M na n kuilame.',
#   'Kuils-y biigã tɩ wĩndg kẽeme.',
#   'B kuilsda bi-puglã.',
#   'Sũmã kuirbame.',
#   'A kuirga a ninã.',
#   'Wãk kukuri.',
#   'a rɩta kukurundi.',
#   'M na n kulame.',
#   'Pʋg-yãan-kulkuugu.',
#   'Raar fãa kullu.',
#   'Yõk n lubã yaa ka pãnga, la gãe n kutẽ wã yaa f ka neda.',
#   'Gãeeng sã n dɩk f kurg / bɛnd tɩ f zoe n pʋg-a, fo me yaa gãeenga.',
#   'Yʋʋm a yiib biig pa belgd na a kuroog ye.',
#   'Wed kursi.',
#   'Fo n kut la f zugdẽ.',
#   'Ka-koaad pa kuud n doog wa tãoos ye.',
#   'Rʋkã kũbundame tɩ zẽedã raag zãnga.',
#   'Yellã ra pak-a lame, la nebã kũm-a lame.',
#   'Ned kõn mum kũum n bas a nao / kars yɩng ye.',
#   'Wẽnd kũun yɩɩd baoobo.',
#   'A kʋʋ rũngã.',
#   'A kʋʋ fu-kãnga wã.',
#   'Kʋ-bil pa solgd yak ye, rɩ-bil n solgd yaka.',
#   'Pa togs-m kʋʋr zabda kʋ-yiri.',
#   'Kʋdem-bull ka ket kʋdem-koom ye.',
#   'Zaamẽ me yaa kʋdemde.',
#   'Fuugã kʋdgame.',
#   'Yɩɩn-kʋdgo.',
#   'A leba a sɩd-kʋdgẽ wã.',
#   'A yaa bãad-kʋdre.',
#   'Kʋgs n waoogd bãoogo.',
#   'Saagã kʋɩɩme n dat n ni.',
#   'Ned kam fãa zãms zu-kʋr tʋkre, tɩ ka zĩis fãa n tar kʋɩds ye.',
#   'Kʋɩɩm yet tɩ koob noom me, roog tɩ d kul n yɩɩde.',
#   'Kʋɩɩm yet tɩ sẽoog / yʋʋmd tʋ la a wa.',
#   'Yellã yaa vẽeneg kʋɩra.',
#   'A kʋkda a zug n kelme.',
#   'Kʋɩlg bas m yam yaa kʋl-koɛɛnga.',
#   'A kʋnda fuugã tɩ ya neere.',
#   'Kʋmb a goamã n togs-do.',
#   'Nif kʋmda a mita.',
#   'Ra kʋms biigã.',
#   'Kelg yaa bõe n tar kʋr-kʋrã?',
#   'Maan-kʋsga.',
#   'Maanã kʋsgame.',
#   'Yãag-yãg kʋʋda kɩɩg tɩ bugum kae n sẽed ye.',
#   '«Yagre» kʋʋg-n-gʋlsga, yaa «yag».',
#   'A Zã kʋʋlame.',
#   'Pag la yiri.',
#   'Piig la a yiibu.',
#   'A laa wʋsgo.',
#   'Mam sagl-a lame, la a ka reeg ye.',
#   'A Tẽne kuilame la a waame.',
#   'Wẽnnaam Sẽn-Ka-Saabo yãka tẽng tom n maan ninsaala. La Wẽnnaam fʋʋsa ninsaal yõ-bogdã pʋga, n ning vɩɩm ninsaal pʋgẽ. La ninsaal lebga nin-vɩɩga.',
#   'F ma wat la!',
#   'Ẽ ! fo waame la?',
#   'La m nonga woto!',
#   'B pʋd-a-la a Tẽne.',
#   'A watame la a laadẽ.',
#   'baa a yembr ka be sẽn ya-a kãseng n yɩɩd a Zã ye. La baoosgo, sẽn yaa-a yao-zʋʋg Wẽnnaam soolmẽ wã, yaa kãseng n yɩɩd a Zã.',
#   'F sã n pa na n rɩ la-wɛdgẽ, bɩ f ra ning n kõ f to ye.',
#   'B laadame.',
#   'Y yibeoog yaa laafɩ?',
#   'Tẽn-laaga.',
#   'Ned pa yãt pesg bedrem n lebg laagd ye.',
#   'Laag nem-kaamã n ningi.',
#   'Sɩlgã laandame.',
#   'A laanda futã.',
#   'Sɩlg laand yĩngr me, a kõb wata tẽnga.',
#   'Bãad kʋdr n são ne laasr kibare.',
#   'Luiila yɩgda lab-labe.',
#   'Yõ-labende.',
#   'Wẽ bãngã n labende.',
#   'Kunkub-labga.',
#   'Zu-labre.',
#   'Ned kõn labs a meng ne naab ye.',
#   'Ad tʋʋmã labsa.',
#   ...],
#  'fr': ["L'enfant a pleuré.",
#   'Levez-vous. Travaillez.',
#   'Il / elle est venu(e).',
#   'Son père est venu.',
#   'Paul et Jean.',
#   'Deux et trois, ça fait cinq.',
#   "Il l'a vendu hier. Il a vendu le cheval hier.",
#   "Proverbe : N'accepte pas qu'un tam-tam joue n'importe comment pour que tu danses n'importe comment.",
#   "Change donc d'attitude. Sinon, je viendrai à toi bientôt et je combattrai ces gens.",
#   'Une autre fois / moment.',
#   "Cela mérite qu'il vient lui-même.",
#   "L'homme est neuf, il ne vaut pas dix. (Proverbe: il est de la nature de l'être humain de n'être pas parfait, il comporte des insuffisances).",
#   'Ne fais pas comme cela, fais plutôt ainsi.',
#   'Or, il y avait une femme qui était malade.',
#   "Le pied de mil semé et le pied de mil non semé ne sont pas identiques. (proverbe disant: il y a une grande différence entre le vrai et le faux. Une photocopie n'équivaut pas à l'original.)",
#   'Proverbe : Untel ne veut pas admette que sa main gauche est morte (Sens: ne pas vouloir admettre la vérité/erreurs).',
#   "La femme est venue les mains vides, elle repartira les mains vides. (Proverbe: au mariage elle rejoint pratiquement le mari les mains vides. C'est au cours de sa vie qu'elle mettra au monde des enfants et aura des biens. En cas de divorce ou décès du mari, elle devrait repartir les mains vides.)",
#   'Ah non! Vous êtes comme ça?',
#   'Voici des enfants.',
#   'Celui-ci est mon fils élu.',
#   'Voici des enfants.',
#   'Il a mangé et pousse un rôt.',
#   "Le Paradis es l'endroit où les justes peuvent se réjouir devant Dieu après la mort.",
#   'Le serpent était le plus rusé de tous les animaux sauvages que le Seigneur avait faits. Il demanda à Eve : «Est-ce vrai que Dieu vous a dit: “Vous ne devez manger aucun fruit du jardin”?»',
#   "Sa mère a dit : «Non, il s'appellera Jean.»",
#   "Non, pas du tout, je n'ai pas appelé!",
#   "Ah! C'est toi?",
#   'Cette eau-là. Cet enfant-là (en question).',
#   "ne dites pas simplement «oui», dites plutôt «oui, s'il vous plaît».",
#   'bière aigre',
#   '«Que Dieu vous donne la santé». «Amen».',
#   'Ceci appartient à qui?',
#   "C'est un arbre facilement cassable.",
#   "Le vent a fait que la grand branche de l'arbre se casse et tombe par terre.",
#   "L'eau a rompu la digue.",
#   "Le fleuve s'est étale sur une grande surface.",
#   'Dis-leur de venir.',
#   "Il (mon père) va t'accompagner.",
#   "Même pas une personne n'est venue.",
#   "Même s'il est venu ...",
#   'Appelle-les.',
#   'Mon grand frère Jean est venu.',
#   "Bien qu'il soit en train de pleuvoir il va venir ici.",
#   "Personne ne peut reconnaître un chiot enragé. (proverbe: on ne peut pas se prononcer sur le caractères futurs d' un enfant, des dirigeants fraîchement élus)",
#   "La force du chien mâle, c'est chez lui. (Proverbe: il a tout le soutien des membres de la famille et rien ne peut lui arriver tant qu'il joue son rôle de protecteur.)",
#   'Les parents de la jeune fille furent étonnés.',
#   "C'est Dieu qui nettoie le derrière du chien qui souffre de la diarrhée. (Proverbe: on ne doit pas perdre espoir quelles que soit les situations.)",
#   "Si un lièvre rapide apparaît, un chien rapide l'attrapera. (Proverbe: quand quelqu'un se croit meilleur, plus intelligent ou plus rusé que les autres, il en trouvera excellent, plus intelligent et plus rusé que lui.)",
#   "On ne lapide pas la patrie avec un caillou, on utilise un morceau de terre. Proverbe (Sens: On doit toujours poser des actions constructives en faveur de son lieu d'origine)",
#   "grande quantité d'argent",
#   "Car il commande même au vent et à l'eau, et ils lui obéissent.",
#   "Allez vous-mêmes en chercher où vous pourrez en trouver. Et sachez qu'il n'y aura pas de réduction sur le nombre exigé de briques.",
#   'Ne vous soucieux de rien:',
#   "Même si tu n'aimes pas le lièvre, il faut reconnaître que ses oreilles sont grandes. (Proverbe: quand une personne excelle dans un domaine donné, on doit le juger de façon objective en reconnaissant son mérite même si elle est un ennemi.)",
#   "L'enfant ne sait pas que son père n'est pas chef / Dieu. (Proverbe: chacun doit agir en fonction des réalités de ses parents et se comporter en conséquence: il ne doit pas leur réclamer ce qu'ils ne sont pas ne mesure de trouver.)",
#   'Tous les gens se sont quittés.',
#   "Tu sais que ce n'est pas moi.",
#   'Voici, prends le cadeau.',
#   'Viens ici !',
#   'Intense chaleur.',
#   "Quand on dit que la hache tue le caïman, il ne s'agit pas de la jeter dans l'eau. (Proverbe: pour qu'une solution soit efficace, il faut l'appliquer avec toute la rigueur qu’elle exige, sinon les résultats escomptés ne seront pas atteints.)",
#   "Si un cheval s'échappe, il retournera à son pieu d'attache (à domicile). (proverbe: la vérité sera toujours rétablie au détriment du mensonge, de même, la justice triomphera de l'injustice)",
#   'Est-il mort quand même ?',
#   'Ils sont en train de blaguer et de rire.',
#   'Va rejoindre ta mère au marché.',
#   "Je n'ai jamais vu cette personne.",
#   'Ils ne sont pas venus ensemble, mais séparément.',
#   'La bifurcation de la route.',
#   'Sépare-les, ne les mélange pas.',
#   'Il est étonné et tremble fortement.',
#   "Ce qu l’œil voit n'a pas besoin d'être dit par le devin. (proverbe: l'évidence n'a pas besoin de preuves.)",
#   "L'endroit a fortement chauffé.",
#   "Viens à l'ombre car aujourd'hui la chaleur est torride.",
#   'Il est arrivé à la bifurcation de la route.',
#   "La santé seulement. C'est la vérité seulement.",
#   'Il ne pourra pas venir, car son ami est malade.',
#   'tu est allé loin.',
#   "Proverbe: C'est Dieu qui épierre le mil de l'aveugle. (sens: on doit toujours garde espoir)",
#   'Sépare les haricots du mil.',
#   'On le gardait lié de chaînes, et les fers aux pieds, mais il rompait ses liens',
#   'Son corps est un peu chaud.',
#   'Je te cherche.',
#   "Les enfants clapotent de l'eau.",
#   'bouche prognathe',
#   "Ce que Dieu a donné dépasse ce que l'on cherche. (Proverbe: dans toute entreprise humaine, Dieu a une place très importante.)",
#   "Quand on veut tuer un chat, on colle des plumes à son museau et on l'accuse d'avoir attrapé une poule. (Proverbe: comme on le dit: quand on veut tuer son chien, on l'accuse de rage)",
#   'Malgré tout, tu vaux mieux.',
#   "Malgré tout tu n'as pas raison.",
#   "Si le joueur de cor souffle en vain dans l’œil (pour faire sortir le brin de saleté), alors le joueur de flûte ne s'y essaye pas ! (proverbe: si celui qui a plus de moyens n'arrive pas à faire quelque chose, celui qui est en manque de moyens n'y arrivera pas)",
#   'Ses affaires / outils sont en désordre.',
#   'son corps est très chaud.',
#   'Ce jour-là elle a accouché.',
#   "Retenue d'eau construite.",
#   'Je laisse tomber, je ne peux plus.',
#   "Le sac s'est cassé et le mil s'est éparpillé.",
#   'Merci. Que Dieu nous donne un autre jour. (À la prochaine)',
#   "Quand le porc-épic est absent de la maison, c'est le hérisson qui fait la libation. (Proverbe: l’intérimaire est appelé à prendre les décisions pour la bonne continuité du service et des affaires pendant l'absence du patron.)",
#   'Il laissa ses affaires entre les mains du gardien des bagages.',
#   "Puisqu'il n'a pas fait confiance, il n'a pas accepté qu'ils traversent son territoire.",
#   "Le pèlerinage du chat n'inspire pas la confiance. (Proverbe, sens: il faut toujours avoir un comportement exemplaire pour être crédible et avoir al confiance des gens)",
#   'Son corps est chaud.',
#   "On épargne un chien à cause de son propriétaire. (Proverbe: la crainte, l'admiration,ou le mépris qu'on a d'un individu est aussi porté sur tout ce qui lui appartient.)",
#   "On ne délaisse pas la tortue pour pourchasser une pintade boiteuse. (Proverbe: quand es opportunités se présentent à quelqu’un, il doit saisir celle qui lui est plus accessible et non celle qui lui paraît meilleur mais difficile d'accès, sinon il va perdre les deux)",
#   'Enfant maladif.',
#   "Le pire ennemi de l'homme est la maladie. (Proverbe: l'homme doit prendre soin de sa santé, car sans la santé,rien ne peut être réalisé.)",
#   'Que Dieu vous couche paisiblement.',
#   "Il s'est assis tranquillement.",
#   'Allez doucement',
#   'Ces enfants (là-bas).',
#   'Ceux-là sont venus ici hier.',
#   'Ceux-là sont venus ici hier.',
#   'Voici leur maison.',
#   'Il a grossi et son ventre est boursouflé.',
#   "L'arbre est devenu touffu.",
#   'mystère; miracle',
#   "Applique de l'huile sur la plaie de l'homme.",
#   'Ralentis ta marche.',
#   'Il dompte des chevaux.',
#   "Il n'y a pas de village intéressant, le tout est de savoir cohabiter. (Proverbe: on doit adopter une bonne conduite, avoir des bonnes relations avec les habitants, bien s'intégrer)",
#   'Même si les œufs du gecko ne se mangent pas, il préfère de se cacher. (proverbe: chacun doit veiller à ses bien pour empêcher leur destruction)',
#   'Ne tiens pas cachées les paroles prophétiques de ce livre, car le moment fixé pour tous ces événements est proche.',
#   'Et lorsque furent accomplis les huit jours pour sa circoncision, il fut appelé du nom de Jean.',
#   "Le huitième jour après la naissance ils vinrent pour circoncire l'enfant.",
#   "A la journée de ne pas chercher à découvrir les secrets de la nuit. (proverbe: chacun pense que la situation de l'autre est meilleure tout simplement parce qu'il en ignore les réalités)",
#   'Les jeunes.',
#   'Il est là-bas.',
#   'Je suis ici.',
#   "Celui qui a une queue n'enjambe pas le feu. (proverbe: toute personne qui a la responsabilité d'autres personnes doit se soucier de ces personnes quand il voudra poser des actes)",
#   "Le tô n'est pas bien fait, il est trop mou et s'écoule.",
#   "Il ne faut pas prendre ton petit coup pour échanger contre un coup violent. (Proverbe: quand on provoque plus fort que soi, il est évident qu'on risque de recevoir une réplique plus forte.)",
#   "C'est la plus petite de toutes les graines; mais quand elle a poussé, c'est la plus grande de toutes les plantes du jardin.",
#   "On ne doit pas voir la grosseur du mouton et se faire passer pour un fossoyeur. (proverbe: nous ne devons pas nous déshonorer, ternir notre image et notre dignité à cause d'un avantage quelconque. Il faut toujours résister aux offres et aux opportunités déshonorantes.)",
#   'La bouche ne mangera pas du bon et raconter du mauvais [de celui qui lui a donné]. (Proverbe)',
#   "Il n'est pas généreux.",
#   'Combien de fois mon frère pourra-t-il pécher contre moi et devrai-je lui pardonner?',
#   'Pardonne-nous nos péchés, car nous aussi, nous pardonnons à quiconque nous offense.',
#   "Il a semé une grain d'arachide.",
#   'Il y a la santé.',
#   'Est-ce que votre père est là?',
#   'Car nous sommes ici dans un lieu désert.',
#   'télécharger des parties de ce long film.',
#   "Il jeté un bâton sur le lièvre et l'a fait tomber.",
#   'Sa dent est branlant sur le point de sortir.',
#   'Ma dent bouge et elle veut tomber.',
#   "L’existence d'un enfant téméraire s'apprécie le jour de danger. (Proverbe)",
#   "Dire que parler n'a pas d'importance, c'est pour consoler la mère du sourd-muet. (proverbe)",
#   "Quand on félicite un enfant parce qu'il cultive bien, il coupe les orteils de son père. (Proverbe: Les félicitations et les encouragements poussent à vouloir faire mieux, à exceller. Ce qui peut engendrer des débordements, des dérapages néfastes. Tout excès nuit.)",
#   "que il = qu'il",
#   'Awa console son enfant.',
#   "C'est pour de vrai ou bien pour s'amuser?",
#   "J'ai reçu une consolation.",
#   "Le ciel est couvert, il se peut qu'il va pleuvoir.",
#   "Quelle peur t'a pris que tu trembles comme ça?",
#   'eau bouseuse.',
#   "Les bœufs ont rendu l'eau trouble.",
#   "Quand un vieux court dans un champ de haricot fleuri, s'il ne pourchasse pas quelque chose, quelque chose le chasse. (Proverbe: l'homme ne prend pas des risques gratuitement, S'il n'y est pas contraint, il voit ses intérêts)",
#   'Pars demain.',
#   'Que Dieu nous donne demain (à nous revoir)',
#   'bouche ébréchée',
#   'Elle a cuit une courge qui est devenu trop cuit et moue.',
#   'Il est décédé après avoir été malade pendant longtemps.',
#   'Le tatoueur a incisé son visage.',
#   "Le tô n'est pas encore très consistant.",
#   'Il est malade.',
#   "L'habit qu'il portait était rayé.",
#   'Habit rayé.',
#   "Épargne une partie du salaire et met le de côte, car on ne sait jamais si on l'a besoin dans l'avenir.",
#   'Il a colmaté sa case.',
#   "Les termites ne s'attaqueront pas aux grands et épargner les petits. (Proverbe: il s'agit d'un traitement de tous les citoyens d'un pays sur un pied d'égalité sans aucune partialité)",
#   'Où est ton enfant ?',
#   'La chèvre a crié ben pour appeler ses petits.',
#   "Si tu n'as rien à donner à l'étranger, il faut le combler de salutations. (proverbe: il faut accorder à l'étranger une hospitalité débordante et exemplaire.)",
#   "Il n'y a pas la moindre goutte d'eau dans son canari.",
#   "L'intelligence de l'enfant ne dépasse pas celui qui le berce. (Proverbe: aucune personne ne peut dire qu'elle est plus intelligente ou plus rusée que tout le monde. Celui qui nous conseille à toujours quelque chose de plus à nous apporter.)",
#   "Le cache-sexe d'aujourd'hui vaut mieux que la culotte (ou le pantalon) de demain. proverbe indiquant: une solution concrète immédiate vaut toujours mieux qu'une solution probable aussi belle soit-elle. Un tiens vaut mieux que deux, tu l'auras)",
#   "Que chacun mange le haricot qui est devant lui. (proverbe: chacun doit s'occuper de ses propres affaires)",
#   "Si tu assistes à la chasse du rat palmiste, si tu ne fais pas du rat un ennemi, tu seras l'ennemi des enfants. (Proverbe: quelle que soit l'issue, l'adulte ne peut s'empêcher d’avoir une certaine responsabilité sur son dos.)",
#   'La rougeole est une maladie contagieuse.',
#   'Il vient demain ou après-demain.',
#   "Si tu tues (ou chasses) ton enfant téméraire, c'est l'enfant téméraire d'autrui qui te tuera. (Proverbe: on ne porte pas atteinte à une connaissance ou un membre de sa famille impunément.)",
#   'Un bon arbre produit de bons fruits et un arbre malade de mauvais fruits.',
#   "L'enfant bien éduqué est l'enfant de tout le monde. (Proverbe: Toute personne qui pose des bonnes actions sans discrimination est l'ami de tout le monde)",
#   "C'est mon fils unique.",
#   "Qu'est-ce que vous a pris que vous courez si vite?",
#   'Dans les ténèbres.',
#   'Le genou a déboîté.',
#   "Le canari a basculé et l'eau s'est versée.",
#   'La femme porte le canari penché.',
#   'Jean est-il venu ?',
#   'Elle est assis avec un air songeur.',
#   'Le berger fait «bii», «bii» pour appeler la chèvre.',
#   'veau, veaux',
#   'Clé (lit. partie de la porte).',
#   '... ce qui doit arriver bientôt.',
#   "C'est petit à petit que le tabac s'écoule. (proverbe: petit à petit l'oiseau fait son nid)",
#   'Attends un peu.',
#   'Petit enfant.',
#   'cheveux entortillé dans tous les sens',
#   'sans bruit',
#   'On ne peut pas faire tourner la roue devant du vélo.',
#   'Roule le vélo dans la maison.',
#   'Ils ont indiqué avec des gestes de leurs mains pour savoir ce que le muet veut.',
#   'Il met du fumier sur le champ de maïs.',
#   'Fil fin.',
#   "L'arbre a repoussé des feuilles et est devenu ombrageux.",
# ...
#   'It is exactly like that.',
#   'The fire is put out.',
#   'When does the month come to an end?',
#   'His garment is completely used up.',
#   'How are you?',
#   'He built a shed.',
#   'Keep an eye on the child.',
#   'The Bambara beans are not well cooked, they are still hard.',
#   'Hard corn (not well cooked).',
#   'The market ban is said on the day of its establishment. (proverb saying: we set the rules of the game from the start, each party must know their rights and obligations to avoid conflicting situations)',
#   'Whoever does not get to the well to draw water, will die of thirst. (proverb indicating: we must avoid spreading false rumours, lies and so on. )',
#   'Pour out the water.',
#   'They had no children because Elizabeth was sterile.',
#   'Put the fire out.',
#   'The gourd containing a talisman does not run dry. (Proverb: the man must not accept to lose everything of value which he has until the source. He must take care to keep this source which will allow him to produce or reconstitute this same thing.)',
#   'He can turn himself into a hyena.',
#   "If you dance while walking forward without being applauded, you don't have to dance to go backwards. (Proverb: When someone delivers his performance to an audience that does not buy into it, he must question himself and improve. We must not persist in mediocrity.)",
#   'Acclaim the king!',
#   'Barren cow.',
#   'Sunday is the resting day of the Christians.',
#   'It is a forbidden thing.',
#   "Who is proud of himself does not despise anyone. (Proverb: Contempt for one's own person can only lead to contempt for others. Therefore, everyone should be proud of himself.)",
#   'He is running hop hop.',
#   'The porridge is thick.',
#   "Our clan's taboo is crocodile meat.",
#   'They are related to each other, they are brothers.',
#   'The stone fell «tong».',
#   'The child weeps and sobs.',
#   'If a sauce made with two guinea fowls is good, it is not necessarily because the woman who is a good cook. (proverb: when all the necessary conditions are met, there will undoubtedly be success in the end)',
#   'He is shaking as he laughs.',
#   'He completely locked the room.',
#   'This thing is very small.',
#   'The door shut with a loud noise.',
#   'My cousin /brother is my kin.',
#   'The water is very cold.',
#   'Knock in the peg and tie the goat there.',
#   'One should not shame his informant. (Proverb: you must protect your sources of information and maintain trust.)',
#   'Where are you going?',
#   'He cut open the calabash fruit and made two calabashes out of it.',
#   'He sent me two strong children to help me.',
#   'The mole-cricket screams shrilly and continues.',
#   "His ears are muffled so he can't hear well.",
#   "If the girl is exulting, let her ask her aunts. (Proverb: whatever joy we have, we should rejoice in moderation because we don't know what tomorrow has in store for us.)",
#   'Small child.',
#   'Not deep well.',
#   'You will be very happy.',
#   "If you don't remove the thorn from your butt, you won't be able to remove the thorn from your foot. (Proverb: one who has not been able to take care of his own problems will not be able to do it for a third person.)",
#   'Do not wait for the ghost to enter the house before closing. (Proverb: To prevent something from happening, you have to do it in time.)',
#   'One can fry the meat.',
#   'He herds sheep.',
#   "If you don't know the spirits of the village, you don't beat the drum. (Proverb, meaning: As a foreigner, always adapt to the laws and customs of your host country)",
#   "Don't eat the meat of a dead animal.",
#   'It is from disagreements of the feet that infirmity is born. (Proverb: In any situation involving various parties, when there are misunderstandings, arguments, quarrels for one reason or another, the cause for which the parties have come together will not be well defended.)',
#   'They refused that it is not the true.',
#   'A negative sentence.',
#   'He heard of the problem and informed me secretly.',
#   'He remained in good condition.',
#   'Dishes are all kinds of sold food.',
#   'The pot is bent to one side.',
#   'Along the path.',
#   'You shall not bear false witness against your neighbour.',
#   'Trust in God.',
#   'He gave me the money.',
#   'I give it back to him.',
#   'He will castrate the male pig.',
#   'god made that the trees grow.',
#   'The mud has become hard.',
#   'Hardened hand.',
#   'Water exists and deep water exists. (Proverb: fame, authority, economic power, difficulties, dangers ... are different in their importance according to individuals, regions, countries and continents, which also makes the difference between individuals, regions and countries.',
#   'The water to put out a fire does not have to be clean. (Proverb: when you are faced with an emergency, anything that can help resolve the situation is desirable. Or, the end justifies the means.)',
#   'A stream broke against that house and could not shake it.',
#   'He knocked at the door «knock-knock».',
#   'Porridge that is not thick.',
#   'Here is the place of the peanut seller.',
#   'To haggle too much, one ends up awakening the vigilance of the merchant. (Proverb: there has to be a compromise. Each party has to be reasonable, otherwise there will be no transactions)',
#   'It is your host who plucks your partridge. (Proverb: when people are together, each takes advantage of the other)',
#   'Elevation for keeping the water.',
#   'A borrowed armpit drum should not be zealously beaten. (Proverb: when you borrow something from someone, you have to take care of it so that you can return it in good condition)',
#   "It's 1000 francs CFA.",
#   'He killed a chicken.',
#   "When the goat's turn to be slaughtered comes, let him lift his chin. (Proverb: When it comes to someone's turn to take responsibility, to do something, he must do it properly.)",
#   "Pay attention, it is serious! He hasn't come, isn't it?",
#   'Our theme is «The live of the couple.»',
#   'hairless head.',
#   'Dry place.',
#   'If you discover that the grass is short, you have to bend down to cut it. (proverb, if you come late, you have to be content with what is left).',
#   'I wrote to you a short letter.',
#   'Dry place',
#   'You are well dressed like that, where do you go?',
#   'May God protect you.',
#   'It is eggs in a sac, that does not break the eggs, it just makes some noise. (proverb meaning: quarrelling does not mean rupture)',
#   'His belly rumbles.',
#   'Hold the shield to fend off all the arrows of the evil person.',
#   'It is hot in the room so he went outside to get some fresh air.',
#   'Hold the child or he will fall down.',
#   'Lead the animals into the stable.',
#   'They shave his head wit a razor blade.',
#   'John seized him at the throat and began to choke him, saying, ‘Pay what you owe me.’',
#   'I got near the town.',
#   'The mouth of a stammerer uses a lot of saliva, but it is better than having to have blood coming out of his mouth. Proverb',
#   'Eating to exceed the capacity of your belly does not prevent you from being hungry the next day. (Proverb: the rational management of our resources, whether they are abundant or not, is an incontestable necessity.)',
#   'Eat without being full and go to sleep without eating. (proverb: an unpleasant situation can deteriorate further)',
#   'Territory directed by a mayor.',
#   'The hard work has weakened him.',
#   'A car has hit him and made him a paralytic.',
#   'They judged that you are guilty.',
#   'He who has a mouth will surely find his way. proverb (meaning: one should not hesitate to get information) Proverb',
#   'He tried hard but without success.',
#   "‹I'm wise›, that's why I grow early okra. (Proverb: when someone fails to achieve their goals or has been the victim of a given situation, they must realize their mistakes, learn from the situation to achieve their goals or to avoid being victimized next time)",
#   'A place that can be farmed.',
#   'Ground-nuts that are not ripe.',
#   'Fold your legs and leave the way free.',
#   'Gather the dirt to a pile.',
#   'We are not ahead of the Nile monitor in the water. (Proverb: in all circumstances, one must show restraint and self-control. One must wait to gather all the proofs of his action to give oneself all the reasons and all the proofs. Hastiness destroys all reason even for that who would be right)',
#   'I am a seller of mats.',
#   'Good tobacco sells itself. (Proverb: the right commodity easily finds a buyer)',
#   'What do you sell?',
#   'Somebody knocks at the door.',
#   'I am asking for water.',
#   'God answered the request of the woman and she gave birth to a boy.',
#   'The thin porridge boils making «kit-kit».',
#   'Teacher, I beg you to look at my son.',
#   'I give you some money.',
#   'Giving more is not hitting more. (Proverb: it is never too much to do well and everyone should always be inclined to do good. On the other hand, we must not make a bad situation worse.)',
#   'Your wife Elizabeth will bear you a son.',
#   'The sting of a bee.',
#   'The generous seeks friendship and the one who refuses (the gift) seeks enmities. (Proverb: the donation creates relations of friendship, good cohabitation and trust. To refuse a donation is to break this chain of relations and gives rise to mistrust).',
#   "Holding a bone for a long time puts doubt in the dog's mind. (Proverb: When you expect something that doesn't see the light of day, you can't help but worry.)",
#   "The dog's body is full of dirt.",
#   'She is brewing beer.',
#   'Are you stupid like that?',
#   "You won't come.",
#   'At that moment.',
#   'It is yellow like dawadawa flour.',
#   'He shaved is head.',
#   'Shaved head.',
#   "If he had known he wouldn't have come.",
#   'He scraped off the grass and the place became nice.',
#   'He is coughing toughly.',
#   'A thorn stung me.',
#   'He goes towards the market.',
#   'May God give health!',
#   'Generous person.',
#   'Go behind the wall.',
#   'Thick porridge.',
#   'They went home.',
#   'The stranger wants to put an end to his stay, now he washes his hands in the clean water jars. (Proverb: When you enjoy hospitality, you have to behave well to have the sympathy of the locals.)',
#   'I will go home.',
#   'Send the child home for the sun set already.',
#   'They gave the girl for marriage.',
#   'The Bambara beans got hard.',
#   'He opened his eyes widely.',
#   'Handle of a hoe.',
#   'he eats like a pig.',
#   'I will go home.',
#   'A very old woman.',
#   'Forever.',
#   'Being thrown to the ground, is lacking strength, but being tossed in the dust, is not having friends who help. (Proverb, meaning: show solidarity whenever needed)',
#   "If a madman grabs your pants and you chase after him, you're a madman too. (Proverb: one must not answer evil with evil)",
#   "A two-year-old doesn't flatter himself with a fictional monster. (Proverb: you can cheat someone once for one reason or another (ignorance, naivety ...) but you cannot cheat him all the time.)",
#   'Bike racing.',
#   'It is you who forges and it is you who are in the bellows. (Proverb: this proverb is said that someone who contradicts himself in his actions: she shows inconsistency in her actions whereas to be understood, this consistency is necessary.)',
#   'When the cultivator bends, he does not stand up empty-handed like the hunter. (Proverb: the agricultural sector is a beneficial sector and as such, deserves to be developed in each country)',
#   'The pot turned over and the sauce is poured out.',
#   'A misfortune got him and people had compassion towards him.',
#   "When you bury a dead person, don't let his feet appear outside. Proverb (do a job correctly)",
#   "God's gift exceeds what we are looking for. (Proverb: In every human endeavour, God has a very important place.)",
#   'He killed the mosquito.',
#   'He used that clothe till the end (it is worn out now).',
#   'Small funerals do not hide from the neighbour, it is a small dish that is hidden from the neighbour. (Proverb: when you are a neighbour, you must share both happy and unhappy events for a harmonious life in community)',
#   'Complaints of not having been informed of the funeral are made at the place of the funeral. (Proverb: when a fault is committed and one must complain, the complaint must be made to the person who committed the fault and not by intermediaries.)',
#   'The river of uses and customs has run out of habits and customs. (Proverb: nowadays, very important parts of our cultures have disappeared and others are in the process of disappearing. It is a bitter observation)',
#   'Yesterday is also history. (Proverb: Yesterday, constitutes the close history but remains all the same a history that the one who lived it can teach to the others)',
#   'The garment got old.',
#   'Ancient song.',
#   'She returned to her former husband.',
#   'He is ill for a long time.',
#   'It is the mahogany trees who honour the lowlands. (Proverb: the honour of every person is due to his fellow men. We must esteem and consider others.)',
#   'The clouds are preparing to rain.',
#   'Proverb: Everybody should learn to carry a load without a cushion because you might find places where there is no cushion.',
#   'The lazy person says that while the ploughing is interesting, coming home is always better. (A proverb that says no matter what someone’s occupation, whether it is interesting or difficult, there are times when you have to quit.)',
#   'The sloth says that the year (or wintering) has only to go and return. (proverb: it is about a person who does not respect his word or his commitments)',
#   'This problem is obvious.',
#   'He places his arms around the head and weeps.',
#   "You can only trust a river when it is dried up. (Proverb, meaning: always be careful, don't take unnecessary risks)",
#   'He embroiders the garment so that it is nice.',
#   'Summarize his talk for us.',
#   'The eye mourns for the person it knows. (proverb: each individual sympathizes with the sorrows of the person he knows.)',
#   "Don't make that the child weeps.",
#   'Listen, what makes that noise?',
#   'Hard okra.',
#   'The okra became old.',
#   'Too much haste kills the palm rat, but there will be no fire to grill. (Proverb: we can seize a great occasion / windfall without it being useful to us because certain conditions will not be met.)',
#   'The short form of the word «plural» is «pl.»',
#   'John got old.',
#   "It's the woman who is (the most important element in) a home. The woman is the showcase of society.",
#   'Ten and two = twelve.',
#   'He laughed a lot.',
#   "I counselled him, but he didn't listen.",
#   'Tene went home and then he came back.',
#   'The LORD God formed the man of dust from the ground. Then God breathed into his nostrils the breath of life. And the man became a living creature.',
#   'Look out, your mother comes!',
#   'Oh! You came?',
#   'Well yes, I like that!',
#   'They gave him the name Tene.',
#   'He comes laughing.',
#   'None is greater than John. Yet the one who is least in the kingdom of God is greater than he',
#   "If you don't eat from a chipped dish, you shouldn't serve your neighbour there. (proverb saying: the treatment that a person does not want others to reserve to him, he should not reserve this treatment for others too)",
#   'They are laughing.',
#   '« How are you (this morning)?»',
#   'Flat area.',
#   'We must not see the size of the sheep and pretend to be a gravedigger. (proverb: we must not dishonour ourselves, tarnish our image and our dignity because of some advantage. We should always resist dishonourable offers and opportunities.)',
#   'Cut a thin layer of fat from the meat.',
#   'The black kite soars in the air.',
#   'He unfolds the garments.',
#   'Even if the hawk hovers in the air, its bones will come to earth. (Proverb: the human being must not ignore his origins because they are unavoidable.)',
#   'It is the sick old man who is better informed of news from the hereafter. (Proverb: one who has experienced something is more apt to talk about it.)',
#   'The bird is flying low.',
#   'Flat nose.',
#   'Hit on the bangle to make it flat.',
#   'A small flat hill.',
#   'A flat and wide head.',
#   'A person cannot compare herself with the chief.',
#   'There is a huge work',
#   ...]}

# %%
save_to_csv(phrases, filename)
# Out:
# Données enregistrées dans phrases_moore2.csv
